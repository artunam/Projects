# %% [markdown]
# <a href="https://colab.research.google.com/github/artunam/Projects/blob/main/Planos_de_fase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# Define el sistema de ecuaciones diferenciales
def sistema(y, t):
    # y[0] y y[1] son las variables de estado
    dydt = [0.5*y[0]-y[1]-0.5*(y[0]*y[0]*y[0]+y[1]*y[1]*y[0]), y[0]+0.5*y[1]-0.5*(y[1]*y[1]*y[1]+y[0]*y[0]*y[1])]
    return dydt

# Condiciones iniciales
tam=[0.0000001,0.01,1,2,-0.0000001,-0.01,-1,-2,1.5,-1.5]

#Definición de variables y de detalles en la gráfica
y0=[]
sol=[]
j=0
plt.figure(figsize=(6, 6))
plt.title('Plano Fase de un Sistema de Ecuaciones Diferenciales')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.legend()
plt.grid(True)

for i in tam:
  y0.append([i,i])
# Tiempo de integración
  t = np.linspace(0, 100, 1000)
# Resuelve el sistema de ecuaciones diferenciales
  sol.append(odeint(sistema, y0[j], t))
# Grafica el plano fase
  plt.plot(sol[j][:, 0], sol[j][:, 1], label='Plano fase')
  j=j+1

#Mostrar gráfica
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# Define el sistema de ecuaciones diferenciales
def sistema(y, t):
    # y[0] y y[1] son las variables de estado
    dydt = [0.5*y[0]-y[1]-0.5*(y[0]*y[0]*y[0]+y[1]*y[1]*y[0]), y[0]+0.5*y[1]-0.5*(y[1]*y[1]*y[1]+y[0]*y[0]*y[1])]
    return dydt

# Condiciones iniciales
tam=[0.0000001,0.01,1,2,-0.0000001,-0.01,-1,-2,1.5,-1.5]

#Definición de variables y de detalles en la gráfica
y0=[]
sol=[]
j=0
plt.figure(figsize=(6, 6))
plt.title('Plano Fase de un Sistema de Ecuaciones Diferenciales')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.legend()
plt.grid(True)

for i in tam:
  y0.append([2,1])
# Tiempo de integración
  t = np.linspace(0, 100, 1000)
# Resuelve el sistema de ecuaciones diferenciales
  sol.append(odeint(sistema, y0[j], t))
# Grafica el plano fase
  plt.plot(sol[j][:, 0], sol[j][:, 1], label='Plano fase')
  j=j+1

#Mostrar gráfica
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy.integrate import odeint

# Definir el sistema de ecuaciones diferenciales
def sistema(y, t):
    dydt = [0.5*y[0]-y[1]-0.5*(y[0]*y[0]*y[0]+y[1]*y[1]*y[0]), y[0]+0.5*y[1]-0.5*(y[1]*y[1]*y[1]+y[0]*y[0]*y[1])]
    return dydt

# Función para generar colores distintos
def generar_colores(num_colores):
    return plt.cm.viridis(np.linspace(0, 1, num_colores))

# Configuración de la gráfica
fig, ax = plt.subplots(figsize=(6, 6))
ax.set(xlim=(-2, 2), ylim=(-2, 2))
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Construcción Progresiva del Plano de Fase')
ax.grid(True)
ax.axhline(y=0,color='k')
ax.axvline(x=0,color='k')

# Lista para almacenar todas las líneas de trayectorias
all_lines = []

# Lista de condiciones iniciales
condiciones_iniciales = [[0.0000001, 0.0000001],[-0.0000001, -0.0000001],
 [0.01, 0.01],[-0.01, -0.01],[1.0, 1.0],[-1.0, -1.0],[1.5, 1.5], [-1.5, -1.5], [2.0, 2.0], [-2.0, -2.0]]

# Número de frames
frames = 1000

# Colores distintos para cada curva
colores = generar_colores(len(condiciones_iniciales))

# Función de inicialización para la animación
#def init():
    # No necesitamos hacer nada en la inicialización
   # return []

# Función de actualización para la animación
def update(frame):
    t = np.linspace(0, 100, frames)

    # Lista para almacenar las líneas de la curva construida en este frame
    current_lines = []

    for i, y0 in enumerate(condiciones_iniciales):
        sol = odeint(sistema, y0, t)
        x = sol[:, 0]
        y = sol[:, 1]

        # Crear una nueva línea para cada curva
        lines, = ax.plot(x[:frame+1], y[:frame+1], color=colores[i], label=f'Curva {i + 1}')
        current_lines.append(lines)

    # Extender la lista de líneas existente con las nuevas líneas creadas en este frame
    all_lines.extend(current_lines)
    return all_lines

# Crear la animación
animation = FuncAnimation(fig, update, frames=frames, init_func=init, blit=True)

# Guardar la animación como archivo mp4
animation.save('phase_plane_animation_multiple_initial_conditions.mp4', writer='ffmpeg', fps=30)

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy.integrate import odeint

# Definir el sistema de ecuaciones diferenciales
def sistema(y, t):
    dydt = [0.5*y[0]-y[1]-0.5*(y[0]*y[0]*y[0]+y[1]*y[1]*y[0]), y[0]+0.5*y[1]-0.5*(y[1]*y[1]*y[1]+y[0]*y[0]*y[1])]
    return dydt

# Función para generar colores distintos
def generar_colores(num_colores):
    return plt.cm.viridis(np.linspace(0, 1, num_colores))

# Configuración de la gráfica
fig, ax = plt.subplots(figsize=(6, 6))
ax.set(xlim=(-2, 2), ylim=(-2, 2))
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Construcción Progresiva del Plano de Fase')
ax.grid(True)
ax.axhline(y=0,color='k')
ax.axvline(x=0,color='k')

# Lista para almacenar todas las líneas de trayectorias
all_lines = []

# Lista de condiciones iniciales
condiciones_iniciales = [[2, 1]]

# Número de frames
frames = 1000

# Colores distintos para cada curva
colores = generar_colores(len(condiciones_iniciales))

# Función de inicialización para la animación
def init():
    #No necesitamos hacer nada en la inicialización
    return []

# Función de actualización para la animación
def update(frame):
    t = np.linspace(0, 100, frames)

    # Lista para almacenar las líneas de la curva construida en este frame
    current_lines = []

    for i, y0 in enumerate(condiciones_iniciales):
        sol = odeint(sistema, y0, t)
        x = sol[:, 0]
        y = sol[:, 1]

        # Crear una nueva línea para cada curva
        lines, = ax.plot(x[:frame+1], y[:frame+1], color=colores[i], label=f'Curva {i + 1}')
        current_lines.append(lines)

    # Extender la lista de líneas existente con las nuevas líneas creadas en este frame
    all_lines.extend(current_lines)
    return all_lines

# Crear la animación
animation = FuncAnimation(fig, update, frames=frames, init_func=init, blit=True)

# Guardar la animación como archivo mp4
animation.save('phase_plane_animation_multiple_initial_conditions.mp4', writer='ffmpeg', fps=30)

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     232         try:
# --> 233             yield self
#     234         finally:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1106                         frame_number += 1
# -> 1107                 writer.grab_frame(**savefig_kwargs)
#    1108
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     358         # Save the figure data to the sink, using the frame format and dpi.
# --> 359         self.fig.savefig(self._proc.stdin, format=self.frame_format,
# ...
